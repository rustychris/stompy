# %% [markdown]
# Streamline Quiver Plot
# --
#
# Example of plotting a streamline quiver plot.

# %%
from stompy.grid import unstructured_grid
from stompy.plot import stream_quiver
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g=unstructured_grid.UnstructuredGrid()
g.add_rectilinear( p0=[0,0],p1=[5,5],nx=31,ny=31) ;
plt.figure(1)
g.plot_edges()
plt.axis('equal') ;
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
cc=g.cells_center()
U=np.c_[ np.sin(cc[:,1]), np.sin(cc[:,0])]
Umag=np.sqrt( (U**2).sum(axis=1))

# %%
zoom=[1,5,0.5,3]

# Regular quiver plot:
plt.figure()
plt.quiver( cc[:,0],cc[:,1], U[:,0], U[:,1], Umag,
           pivot='middle')
plt.axis('equal')
plt.axis(zoom) ;
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# Stream quiver:
sq=stream_quiver.StreamlineQuiver(g,U,streamline_count=200,max_dist=1.0,
                                  min_clearance=0.2)
# Out:
# INFO:join_features:0 open strings, 1 simple polygons
# INFO:join_features:Building index
# INFO:join_features:done building index
# INFO:join_features:Examining largest poly left with area=25.000000, 0 potential interiors
# Edge 0/1860, 0 cycles
# ****-***-*-*-*********-**-**--***-*****-*-***-*-*-*-*--****-****--*-*-*--*--*--*--*****-*--*-*-*-*-*-*-*--***-*-*-*--*--*--*-*-*--*--*--*--*--*-*-*--*--*-*-*--*..*..*--*--*--*--*--*-*--*-*-*--*--*-**--*--*-*--*--*--*--*--*--*-*-*--*--*--*--*--*--*--*--***--*--*--*--*--*--*-*-*..*..*--*--*--*..*--*--*--*-*-*..*--*--*--*--*-*--*--*--*--*..*--*--*--*--*--*--*-*-*--*--*--*-*-*--*..*--*-*-*--*..*--*--*--*--*--*-*-*--*--*..*..*--*-*--*-*--*--*--*--*-*-*--*--*--*--*--*--

# %%
plt.figure()
sq.size=0.02
sq.cmap='viridis'
q=sq.plot_quiver(lw=1.2)
plt.axis('equal')
plt.axis(zoom)
# Out:
# <img src="data:image/png;base64,..." width="432">
# [1, 5, 0.5, 3]
